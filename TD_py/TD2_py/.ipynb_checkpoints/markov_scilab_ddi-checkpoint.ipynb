# %% [markdown]
# $\newcommand\E{{\mathbf E}}$
# $\newcommand\indi[1]{{\mathbf 1}_{\displaystyle #1}}$
# $\newcommand\inde[1]{{\mathbf 1}_{\displaystyle\left\{ #1 \right\}}}$
# $\newcommand{\ind}{\inde}$
# $\newcommand\P{{\mathbf P}}$

# %% [markdown]
# # Un test d'équirépartition

# %%
import numpy as np;
import math;
import random;
import matplotlib.pyplot as plt;
import pandas as pd;

# %% [markdown]
# ## Etude par simulation

# %% [markdown]
# On commence par construire un test d'équirpartition d'une suite de
# $100$ tirages à pile ou face.
#
# On simule des tirages à pile ou face
# répétés. A partir de ce tirage on calcule le nombre de pile
# consécutifs maximum dans le vecteur.

# %%
def tirage_pf(n,p):
    # Effectue n tirage a Pile (P) ou face (F) (1/2,1/2)
    X="";
    for i in range(n):
        U=random.random();
        if U <= p:
            X=X+'P'
        else:
            X=X+'F'
    return X

def max_length(U):
# Calcule le nombre maximum de P consecutifs
# dans la suite U
    MAX=0;N=0;
    for n in range(len(U)):
        if U[n]=='P':
            N=N+1
        else:
            N=0
        MAX=max(MAX,N);
    return MAX

# %% [markdown]
#  On aura besoin de tracer des histogrammes.

# %%
def histo_discret(samples, maxsize,titre):
# histogramme de tirages selon une loi discrète à valeurs entières
# supposé prendre des valeurs entre 0 et max.
    size, scale = 10000, 10
    my_histo = pd.Series(samples)
    my_histo.plot.hist(grid=True, bins=20, rwidth=0.9, color='#607c8e')
    plt.title(' ')
    plt.xlabel(titre)
    plt.ylabel(' ')
    plt.grid(axis='y', alpha=1)

# %% [markdown]
# ### Question 1

# %% [markdown]
#  Faire $1000$ tirages du nombre maximum de $P$ et en tracer un
#   histogramme.  On calcule par simulation une approximation de la loi
#   du nombre maximum de piles consecutifs (un histogramme d'un grand
#   nombre de tirages i.i.d.).

# %%
def main_1():
    p=1.0/2.0;
    # On teste cette fonction avec N=20
    # rand(1:20) renvoie 100 tirages uniformes sur l'intervalle [0,1]
    U=tirage_pf(20,p)# 20 tirages a pile ou face 1/2,1/2  (1=Pile,0=Face)
    max_length(U)# nombre mximum de P consecutifs

    # On effectue 1000 tirages avec N=100
    N=100;
    Taille=100000;# nbre de simulation
    X=np.zeros(Taille);
    for i in range(Taille):
        U=tirage_pf(N,p);
        X[i]=max_length(U);
    #histo_discret(X, Taille, 'Loi de la longueur maximale pour 10 000 simulation de longueur 100')
 
    histo=np.zeros(21);
    for i in range(21):
        histo[i]=np.size(np.where(X==i))/(1.0*Taille);
    plt.bar(range(20), histo[0:20])
    plt.xlabel('Loi de la longueur maximale pour 10 000 simulation de longueur 100')

# %%
main_1()

# %% [markdown]
# ### Question 2

# %% [markdown]
#  Montrer que le nombre de piles successifs jusqu'à l'instant courant
#   est une chaîne de Markov à valeurs dans ${\mathbf N}$ de matrice de
#   transition $P(x,x+1)=1/2$, $P(x,0)=1/2$. Simuler et tracer de
#   trajectoires de cette chaîne.

# %%
def trajectoire(U):
# On calcule la trajectoire de X
    X=np.zeros(len(U)+1);
    val=0;
    for n in range(len(U)):
        if U[n]=='P':
            val=val+1;
        else:
            val=0;
        X[n+1]=val;
    return X;

# %%
def trajectoire(U):
# On calcule la trajectoire de X
    X=np.zeros(len(U)+1);
    val=0;
    for n in range(len(U)):
        if U[n]=='P':
            val=val+1;
        else:
            val=0;
        X[n+1]=val;
    return X;

def main_2():
  N=100;
  p=1.0/2.0;

  # On trace Nbre trajectoire de X
  Nbre=2
  for i in range(Nbre):
    U=tirage_pf(N,p);
    X=trajectoire(U);
    plt.plot(X);
    
main_2()

# %% [markdown]
# # Calcul exact de la probabilité

# %% [markdown]
# On va calculer exactement la probabilité de voir au moins $l$
# piles consécutifs.

# %% [markdown]
# ### Question 3

# %% [markdown]
#  Calculer la matrice de transition de la chaîne arrêté en $l$,
#   l'implementer en {\tt Scicoslab}. En déduire la probabilité d'avoir au
#   moins $l$ pile consécutifs pour $l=0,\ldots,20$.

# %%
def proba(N,l,p):
    # Calcule la probabilite de voir au moins l piles consecutifs
    # dans N tirages a pile (p) ou face (1-p)

    # la matrice de transition de la chaîne arrêtée en l
    # de taille (l+1,l+1)
    P=np.zeros((l+1,l+1))
    P[0:l,0]=1-p
    P[0:l,1:l+1]=p*np.eye(l)
    P[l,l]=1
    
    # Sa puissance N ième
    PN=np.linalg.matrix_power(P,N)
    return PN[0,l]

# %%
l=2
p=1/2
P=np.zeros((l+1,l+1))
P[0:l,0]=1-p
P[0:l,1:l+1]=p*np.eye(l)
P[l,l]=1
P
# Out:
# array([[0.5, 0.5, 0. ],
#        [0.5, 0. , 0.5],
#        [0. , 0. , 1. ]])

# %% [markdown]
# ### Question 4

# %% [markdown]
# Calculer la loi du nombre maximum de piles consécutifs.

# %%
def calculer_loi(N,p):
  MAXMAX=50;# a choisir assez grand (mais pas trop ...)
  loi=np.zeros(MAXMAX+1)
  
  previous=1;# proba d'avoir au moins 0 pile = 1 !
  # le support de la loi est [0,1,...,N] que l'on tronque en MAXMAX
  for l in range(min(N,MAXMAX)+1):
    current=proba(N,l+1,p); # proba d'avoir au moins l+1 pile
    loi[l]=previous - current;# proba d'avoir exactement l pile
    previous=current;
  return loi

# %% [markdown]
# Comparer avec les simulations précédentes. Vérifier que
#   $\P(X=3)$ est du même ordre que $\P(X=10)$.

# %%
def main_3():
    # On teste avec N=1 et N=2, p=1/2
    # Pour N=1, 0 pile avec proba 1/2 et 1 pile avec proba 1/2
    calculer_loi(1,1/2.0)
    # Pour N=2, on doit trouver (1/4,1/2,1/4) pour (0,1,2)
    calculer_loi(2,1/2.0)
    # en principe ca marche ...
  
    N=100;p=1.0/2.0;
    loi=calculer_loi(N,p);
    sum(loi) # on verifie que ca somme a 1
  
    # dessin
    plt.bar(range(20), loi[0:20])
    
    print("proba d'avoir 3 (ou moins) piles consécutifs: ",np.sum(loi[1:4]))
    print("proba d'avoir 10 (ou plus) piles consécutifs: ",np.sum(loi[11:20]))   
    
    # comparaison avec les simulations
    Taille=10000;
    X=np.zeros(Taille);
    # On fait 10000 tirages
    for i in range(Taille):
        U=tirage_pf(N,p);
        X[i]=max_length(U);
  
    # on calcule l'histogramme empirique
    histo=np.zeros(21);
    for i in range(21):
        histo[i]=np.size(np.where(X==i))/(1.0*Taille);
        
    # on regarde si l'histogramme empirique est proche du calcul exact
    epsilon=np.linalg.norm(loi[0:20]-histo[0:20])
    # epsilon doit etre "petit", pour bien faire il faudrait faire un
    # test du |$\xi^2$| pour savoir ce que "petit" veut dire ici.
    print("epsilon = ",epsilon," --- petit en principe.")

# %%
main_3()
# Out:
# proba d'avoir 3 (ou moins) piles consécutifs:  0.027284957701160018
# proba d'avoir 10 (ou plus) piles consécutifs:  0.021990165542464156
# epsilon =  0.008851045440394827  --- petit en principe.

# %% [markdown]
# # Test du critère

# %% [markdown]
# ### Question 5

# %% [markdown]
# Vérifier que, pour des tirages aléatoires, le test proposé ("obtenir un run
# plus grand que $4$") fonctionne dans la plupart des cas (dans $97\%$ des cas!),
# mais pas toujours.

# %%
def main_4():
# Test du critère lorsque les tirages sont aléatoires
# Ca marche "souvent" mais pas "toujours".
    N=100;
    p=1/2.0;
    Taille=100;
    for i in range(Taille):  
        U=tirage_pf(N,p);
        if (max_length(U) >= 4) :
            print("*",end='')
        else:
            # Ca arrive "rarement" mais ca arrive 3 fois sur 100 quand même
            print("!",end='');

# %%
main_4()
# Out:
# **!********************************!****************************************************************

# %% [markdown]
# # Comment le loi varie t'elle en fonction de $N$ ?

# %% [markdown]
# On regarde ce qui se passe lorsque $N$ devient grand.

# %% [markdown]
# ### Question 6

# %% [markdown]
# Calculer le maximum de vraisemblance de la loi du "run
#   maximum" en fonction de $N$ ($N=100$, $N=500$, $N=1000$).

# %%
def main_5():
# Calcul du maximum de vraisemblance de la loi 
# imax = indice du maximum,  m = le maximum
    p=1.0/2.0;
    print('N: [indice du maximum de vraisemblance] -> [valeur du maximum]\n')
    for N in [10,100,1000]:
        loi=calculer_loi(N,p);
        m=max(loi);
        imax=np.argmax(loi);
        print (N,": ",imax,' -> ',m)

# %%
main_5()
# Out:
# N: [indice du maximum de vraisemblance] -> [valeur du maximum]
#
# 10 :  2  ->  0.3515625
# 100 :  5  ->  0.26401597994641235
# 1000 :  9  ->  0.23879124004379726

# %% [markdown]
# ### Question 7

# %% [markdown]
#  Vérifier que la moyenne du ''run maximum'' varie presque linéairement en
# fonction de $\log(N)$.

# %%
def moyenne(loi):
  return sum(range(np.size(loi)) * loi)
#-------------------------------------------------------
def main_5_bis():
# La moyenne varie (approximativement) comme C log(N).
# Ca peut se prouver.
    p=1.0/2.0;
    valeurs=[10,50,100,500,1000,5000,10000];
    x=np.zeros(np.size(valeurs));
    y=np.zeros(np.size(valeurs));
    i=0;
    for N in [10,50,100,500,1000,5000,10000]:
        loi=calculer_loi(N,p);
        x[i]=math.log(N);
        y[i]=moyenne(loi);
        # print (N,': ',y[i],' ?=? ',x[i])
        i=i+1;
    plt.plot(x,y);

# %%
main_5_bis()

# %% [markdown]
# Ca ressemble beaucoup à une droite mais ça n'en n'est pas une !

# %% [markdown]
# # Calcul du prix d'une option européenne dans le modèle de Cox-Ross

# %% [markdown]
# ## Simulation du modèle

# %% [markdown]
# On considère le chaîne de Cox-Ross~:
# \[
# X_0=x_0, X_{n+1}= X_{n} \left(d\inde{U_{n+1}=P}+u\inde{U_{n+1}=F}\right).
# \]
# avec $N=10$, $x_0=100$, $p=1/2$, $u=1+1/N$, $d=1-1/N$.
#
# On cherche à calculer $\E(f(X_N))$ où $f(x)=\max(x-K,0)$ avec $K=100$.

# %% [markdown]
# ### Question 8

# %% [markdown]
# Simuler cette chaîne de Markov.

# %%
def simul_cox_ross(N,x_0,p,u,d):
  U=np.random.binomial(1,p,N);# tirages a pile ou face (p,1-p)
  X=np.zeros(np.size(U));
  X[0]=x_0;
  for i in range(np.size(U)-1):
    if U[i+1]==0: 
        X[i+1]=X[i]*u
    else:
        X[i+1]=X[i]*d;
  return X

# %%
def main_6():
  N=50;
  sigma=0.3;
  p=1.0/2.0;u=1.0-sigma/math.sqrt(N);d=1.0+sigma/math.sqrt(N);
  x_0=100;

  X=simul_cox_ross(N,x_0,p,u,d);
  plt.plot(X);

# %%
main_6()
main_6()

# %% [markdown]
# ##  Une version récursive de l'algorithme de calcul de prix

# %% [markdown]
# ### Question 9

# %% [markdown]
# Ecrire une version récursive de l'algorithme de calcul de prix. On recopie l'équation obtenue dans le cours.
#
# Tester l'algrithme pour $N$ petit ($N \leq 10$). Vérifier que pour $N\geq 20$ on risque d'attendre longtemps
# le résultat !

# %%
K=100;
def f(x):
  return max(x-K,0);
#-------------------------------------------------------
def prix_recursif(x,k,N,p,u,d):
    if (k==N):
        return f(x)
    else:
        return p*prix_recursif(x*u,k+1,N,p,u,d)+(1-p)*prix_recursif(x*d,k+1,N,p,u,d)
#-------------------------------------------------------
def prix_slow(x,N,p,u,d):
  return prix_recursif(x,0,N,p,u,d);

# %%
N=10;
# On choisit des paramètres pour converger 
# vers le modèle de Black et Scholes.
sigma=0.3;
p=1.0/2.0;d=1.0-sigma/math.sqrt(N);u=1.0+sigma/math.sqrt(N);
x_0=100;
prix_slow(x_0,N,p,u,d)  # Recommencer avec N=20 pour savoir ce que slow veut dire !
# Out:
# 12.078135725435745

# %% [markdown]
# ## Une version itérative de l'algorithme de calcul de prix

# %% [markdown]
# ### Question 10

# %% [markdown]
#  Ecrire une version efficace (itérative) de l'algorithme de calcul de prix.

# %%
def inc(n):
# Permet de faire comme si les tableaux était indicés 
# à partir de 0 (et non de 1)
 return n+1;
#-------------------------------------------------------
def prix(x_0,N,p,u,d):
    # U=zeros(inc(N),inc(N))
    U=np.zeros([N+1,N+1])
    for k in range(N+1):
        U[N,k] = f(x_0 * pow(u,k) * pow(d,N-k))
    for n in range(N-1,-1,-1): # le temps decroit de N-1 a 0
        for k in range(0,n+1): # [0:n]
            U[n,k] = p*U[n+1,k+1]+(1-p)*U[n+1,k]
    return U[0,0]

# %% [markdown]
#  Comparer le résultat des deux versions de l'algorithme.

# %%
def main_7():
  N=10
  sigma=0.3
  p=1.0/2.0
  d=1.0-sigma/math.sqrt(N)
  u=1.0+sigma/math.sqrt(N)
  K=100.0;x_0=100.0;

  prix(x_0,N,u,d,p)

  # Les deux algos font ils le même chose ?
  # on verifie : prix_slow(x_0,N) \approx prix(x_0,N)
  print ("Différence entre les 2 résultats: ", abs(prix_slow(x_0,N,p,u,d) - prix(x_0,N,p,u,d)),"\n")

main_7()
# Out:
# Différence entre les 2 résultats:  7.105427357601002e-15

# %% [markdown]
# Tracer la fonction $x\to u(0,x)$ pour $x\in [80,120]$.

# %%
sigma=0.6
N=200
d=1-sigma/math.sqrt(N)
u=1+sigma/math.sqrt(N)
p=1.0/2.0;

largeur=100
vmin=50
courbe=np.zeros(largeur+1);
x_values=np.arange(vmin,vmin+largeur+1);

n=-1;
for x in x_values:
    n=n+1;
    courbe[n]=prix(x,N,p,u,d);
plt.plot(x_values,courbe);

# %% [markdown]
# ### Question 10

# %% [markdown]
# Que constatez vous lorsque $N$ augmente ($N=10,100,200,500$) et
#   que l'on choisit $u$ et $d$ en fonction de $N$ de la façon suivante:
# $$
#    u=1+\frac{\sigma}{\sqrt{N}}\; \mbox{ et }\; d=1-\frac{\sigma}{\sqrt{N}}.
# $$

# %%
def main_8():
# Avec cet algorithme on peut augmenter N
# mais il faut renormaliser convenablement u et d pour
# rester borné.
# Essayer avec N=10,100,200,...,1000
    sigma=0.6
    largeur=50
    vmin=50
    courbe=np.zeros(largeur+1);
    x_values=np.arange(vmin,vmin+largeur+1);
    for N in [3,5,10,20,50,100,200]:
        d=1-sigma/math.sqrt(N)
        u=1+sigma/math.sqrt(N)
        p=1.0/2.0;
 
        n=-1;
        for x in x_values:
            n=n+1;
            courbe[n]=prix(x,N,p,u,d);
        plt.plot(x_values,courbe);
    
    n=-1;
    for x in x_values:
        n=n+1;
        courbe[n]=max(x-K,0);
    plt.plot(x_values,courbe);
    # Ca converge, mais vers quoi ? Vous verrez ça en 2A.
    
main_8()

# %% [markdown]
# # Un cas numériquement délicat~: les options sur moyenne

# %% [markdown]
# On cherche maintenant à évaluer $\E(f(S_N))$ où $S_n=X_1+\cdots+X_n$.
#
#  Pourquoi le processus $(S_n,n\geq 0)$ n'est il pas une chaîne de
#   Markov ? Vérifier que le couple $((X_n,S_n),n\geq 0)$ est une chaine
#   de Markov de matrice de transition ($0$ sinon)
#   \[
#   P((x,s), (xu,s+xu))=p,\quad P((x,s), (xd,s+xd))=1-p.
#   \]
#   issue de $(x_0,0)$ à l'instant $0$.  En déduire que
#   $\E(f(S_N))=u(0,x_0,0)$ où est la solution unique de
#   \begin{equation}\label{eq:rec}
#     \left\{
#       \begin{array}{l}
#         u(n,x) = p u(n+1,xu,s+xu) + (1-p) u(n+1,xd,s+xd),\quad n< N\\
#         u(N,x,s) = f(s),
#       \end{array}
#     \right.
#   \end{equation}
#
# Ecrire un algorithme récursif (lent) qui résoud l'équation précédente ($N\leq 10$!) et permet
# de calculer $\E(f(S_N))$.

# %%
def f_moy(x,s,N):
    return max((s/N)-K,0)

def prix_moyenne(x,s,k,N,p,u,d):
  if (k==N):
      return f_moy(x,s,N)
  else:
      return p*prix_moyenne(x*u,s+x*u,k+1,N,p,u,d)+(1-p)*prix_moyenne(x*d,s+x*d,k+1,N,p,u,d)

def prix_slow_moyenne(x,N,p,u,d):
  return prix_moyenne(x,x,0,N,p,u,d);

# %%
def main_9():
  N=10
  sigma=0.3
  p=1.0/2.0
  d=1.0-sigma/math.sqrt(N)
  u=1.0+sigma/math.sqrt(N);
  x_0=100.0;K=100.0;

  # Ca marche mais ce n'est pas très efficace ...
  print('Prix option sur moyenne: ',prix_slow_moyenne(x_0,N,p,u,d),'\n')

main_9()
# Out:
# Prix option sur moyenne:  13.18627110107544

# %%
def liste_moyenne_rec(x,s,k,N):
# On constitue la liste des points visités par la chaine
# à l'instant N, en partant de de (x,s) à l'instant k.
# Si un point est visité deux fois, il y figure 2 fois.
    # print k, N, x, s
    if (k==N):
        liste=[];
        liste.append([x,s]);
        return liste
    else:
        liste_up = liste_moyenne_rec(x*u,s+x*u,k+1,N);
        liste_down = liste_moyenne_rec(x*d,s+x*d,k+1,N);
        liste_up.extend(liste_down);
        return liste_up;
    
def liste_moyenne(x,N):
  # On part de (x,s=x) a l'instant 0
  return liste_moyenne_rec(x,x,0,N)

def main_10():
  x_0=100
  N=10
  liste=liste_moyenne(x_0,N)

  # Tri des points selon les valeurs de la somme.
  # Les valeurs de x peuvent etre egales, mais pas celle de s.
  # Nous allons le verifier.
  liste.sort();

  # On regarde si tous les points sont differents
  # en parcourrant le tableau ainsi classé
  epsilon=0.00001
  Taille=len(liste)
  match=[]
  for i in range(Taille-1):
    if (np.linalg.norm(np.asarray(liste[i]) - np.asarray(liste[i+1])) < epsilon):
      print ('Warning: (', liste[i][0],',',liste[i][1], ') ~ (',liste[i+1][0],',',liste[i+1][1],')\n')
      match.append([liste[i][0],liste[i][1],liste[i+1][0],liste[i+1][1]]);
                                      
  if len(match) == 0: 
     print ("Aucun point n'est dupliqué.\n")
        
main_10()
# Out:
# Aucun point n'est dupliqué.

# %%
x_0=100
N=20
liste=liste_moyenne(x_0,N)

# Tri des points selon les valeurs de la somme.
# Les valeurs de x peuvent etre egales, mais pas celle de s.
# Nous allons le verifier.
liste.sort();
#liste
# Out:
# [[42.01875900991849, 1408.6497151998549],
#  [45.74213855749462, 1500.2210795508283],
#  [45.74213855749462, 1524.6121971800176],
#  [45.74213855749463, 1443.4886749346017],
#  [45.74213855749463, 1448.7556349351912],
#  [45.74213855749463, 1465.9984825195436],
#  [45.74213855749463, 1472.2627656105399],
#  [45.74213855749463, 1478.8045950176438],
#  [45.74213855749463, 1485.6362677517768],
#  [45.74213855749463, 1492.7706256571687],
#  [45.74213855749463, 1508.0016344315404],
#  [45.74213855749463, 1516.126915805779],
#  [45.742138557494634, 1412.373094747431],
#  [45.742138557494634, 1416.2614429373705],
#  [45.742138557494634, 1428.991024173323],
#  [45.742138557494634, 1438.4451731219715],
#  [45.74213855749464, 1420.3220688963993],
#  [45.74213855749464, 1424.5626055905673],
#  [45.74213855749464, 1433.6156489692994],
#  [45.74213855749464, 1454.2559536975125],
#  [45.74213855749464, 1459.9999704517227],
#  [49.79545538979722, 1522.364879021097],
#  [49.79545538979722, 1532.6567820030532],
#  [49.79545538979722, 1538.1472001916022],
#  [49.79545538979722, 1543.8808777156546],
#  [49.79545538979722, 1546.7559966502863],
#  [49.79545538979722, 1557.0478996322424],
#  [49.79545538979722, 1562.5383178207915],
#  [49.79545538979722, 1568.271995344844],
#  [49.795455389797226, 1508.5073001112494],
#  [49.795455389797226, 1517.5440480118998],
#  [49.795455389797226, 1527.3993025304646],
#  [49.795455389797226, 1532.8984177404386],
#  [49.795455389797226, 1541.935165641089],
#  [49.795455389797226, 1551.7904201596539],
#  [49.79545538979723, 1451.7748954950227],
#  [49.79545538979723, 1457.0418554956123],
#  [49.79545538979723, 1460.8116433956732],
#  [49.79545538979723, 1466.0786033962627],
#  [49.79545538979723, 1474.2847030799646],
#  [49.79545538979723, 1475.9243773868266],
#  [49.79545538979723, 1480.548986170961],
#  [49.79545538979723, 1481.191337387416],
#  [49.79545538979723, 1483.321450980615],
#  [49.79545538979723, 1486.6817555759649],
#  [49.79545538979723, 1487.0908155780648],
#  [49.79545538979723, 1489.5857340716113],
#  [49.79545538979723, 1493.9224883121979],
#  [49.79545538979723, 1496.1275634787153],
#  [49.79545538979723, 1497.9157518623388],
#  [49.79545538979723, 1498.4341849717684],
#  [49.79545538979723, 1501.0568462175897],
#  [49.79545538979723, 1502.9592362128483],
#  [49.79545538979723, 1503.6597686165487],
#  [49.79545538979723, 1503.9246031603175],
#  [49.79545538979723, 1504.274396383131],
#  [49.79545538979723, 1504.6984680627647],
#  [49.79545538979723, 1509.65828068437],
#  [49.79545538979723, 1510.0935941182402],
#  [49.79545538979723, 1510.1888862513138],
#  [49.79545538979723, 1511.2402974698687],
#  [49.79545538979723, 1512.927747540556],
#  [49.79545538979723, 1515.6459954304692],
#  [49.79545538979723, 1515.9225637753661],
#  [49.79545538979723, 1516.2878549919615],
#  [49.79545538979723, 1516.7307156584177],
#  [49.79545538979723, 1518.0719702040017],
#  [49.79545538979723, 1521.8990028119017],
#  [49.79545538979723, 1521.9102785214654],
#  [49.79545538979723, 1522.4643931824703],
#  [49.79545538979723, 1523.5623883925507],
#  [49.79545538979723, 1524.4131363662],
#  [49.79545538979723, 1525.2063281093936],
#  [49.79545538979723, 1525.324602892612],
#  [49.79545538979723, 1528.1632859028978],
#  [49.79545538979723, 1528.4521079285696],
#  [49.79545538979723, 1528.6655140123203],
#  [49.79545538979723, 1529.2960659166033],
#  [49.79545538979723, 1530.6967462979426],
#  [49.79545538979723, 1533.4498842668504],
#  [49.79545538979723, 1534.705115310002],
#  [49.79545538979723, 1535.2837806627026],
#  [49.79545538979723, 1536.4304238219952],
#  [49.79545538979723, 1537.3188651697453],
#  [49.79545538979723, 1540.4373368837653],
#  [49.79545538979723, 1541.536788044135],
#  [49.79545538979723, 1542.4181385680945],
#  [49.79545538979723, 1545.9277550723143],
#  [49.79545538979723, 1548.5626182580038],
#  [49.79545538979723, 1548.6711459495268],
#  [49.79545538979723, 1549.868592461754],
#  [49.79545538979723, 1551.661432596367],
#  [49.79545538979723, 1554.0530364465528],
#  [49.79545538979723, 1556.1215998431862],
#  [49.79545538979723, 1557.6491473424662],
#  [49.79545538979723, 1559.7867139706054],
#  [49.79545538979723, 1562.00773394268],
#  [49.79545538979723, 1562.6516539573577],
#  [49.79545538979723, 1563.9021547238985],
#  [49.79545538979723, 1565.7744287167047],
#  [49.79545538979723, 1569.142091848072],
#  [49.79545538979723, 1569.4710296805692],
#  [49.79545538979723, 1572.027436098137],
#  [49.79545538979723, 1574.2597100909431],
#  [49.79545538979723, 1576.579134924723],
#  [49.79545538979723, 1576.5925457417316],
#  [49.79545538979723, 1580.5127174723757],
#  [49.79545538979723, 1584.0295888183823],
#  [49.79545538979723, 1584.3731006224436],
#  [49.79545538979723, 1587.042771586547],
#  [49.79545538979723, 1591.7961387003093],
#  [49.79545538979723, 1591.8101436990946],
#  [49.79545538979723, 1592.4983819966822],
#  [49.79545538979723, 1593.8621473097585],
#  [49.79545538979723, 1599.9354250733331],
#  [49.79545538979723, 1600.9836633709208],
#  [49.79545538979723, 1608.4207064475715],
#  [49.79545538979723, 1616.1872563294985],
#  [49.79545538979723, 1624.2979121972635],
#  [49.79545538979723, 1632.7679200650284],
#  [49.79545538979723, 1641.613201439267],
#  [49.79545538979724, 1437.277244733744],
#  [49.79545538979724, 1446.3139926343945],
#  [49.79545538979724, 1446.7313936823925],
#  [49.79545538979724, 1447.5419917669044],
#  [49.79545538979724, 1452.808951767494],
#  [49.79545538979724, 1455.768141583043],
#  [49.79545538979724, 1456.1953429243295],
#  [49.79545538979724, 1461.462302924919],
#  [49.79545538979724, 1465.6324744048704],
#  [49.79545538979724, 1470.0517993518463],
#  [49.79545538979724, 1470.666897914238],
#  [49.79545538979724, 1470.89943440546],
#  [49.79545538979724, 1475.9338579148275],
#  [49.79545538979724, 1476.3160824428426],
#  [49.79545538979724, 1478.7051505092713],
#  [49.79545538979724, 1482.8579118499465],
#  [49.79545538979724, 1484.9694336002676],
#  [49.79545538979724, 1488.1422819898123],
#  [49.79545538979724, 1489.6895845840795],
#  [49.79545538979724, 1491.5112630073716],
#  [49.79545538979724, 1493.17670549918],
#  [49.79545538979724, 1494.4065650808086],
#  [49.79545538979724, 1496.8239424894714],
#  [49.79545538979724, 1498.3429357415046],
#  [49.79545538979724, 1499.4409885901762],
#  [49.79545538979724, 1500.9483944879125],
#  [49.79545538979724, 1505.4772936468964],
#  [49.79545538979724, 1505.98281799728],
#  [49.79545538979724, 1507.7800672220455],
#  [49.79545538979724, 1512.0549512638431],
#  [49.79545538979724, 1512.8144907314131],
#  [49.79545538979724, 1514.9144251274374],
#  [49.79545538979724, 1519.948848636805],
#  [49.79545538979724, 1520.1802326380816],
#  [49.79545538979724, 1520.7083024212682],
#  [49.79545538979724, 1528.8335837955067],
#  [49.79545538979724, 1530.1454339018092],
#  [49.79545538979724, 1535.1798574111767],
#  [49.79545538979724, 1538.2707152760477],
#  [49.79545538979724, 1543.3051387854152],
#  [49.79545538979725, 1420.3147597696732],
#  [49.79545538979725, 1428.6082894568203],
#  [49.79545538979725, 1432.8488261509883],
#  [49.79545538979725, 1433.0443410056257],
#  [49.79545538979725, 1441.6976921630508],
#  [49.79545538979725, 1441.9018695297204],
#  [49.79545538979725, 1442.4984899542742],
#  [49.79545538979725, 1450.9386174303709],
#  [49.79545538979725, 1451.1518411116992],
#  [49.79545538979725, 1460.5889725922402],
#  [49.79545538979725, 1462.5421742579335],
#  [49.79545538979725, 1465.6233961016078],
#  [49.79545538979725, 1468.2861910121437],
#  [49.79545538979725, 1471.578922158584],
#  [49.79545538979725, 1477.3229389127941],
#  [49.79545538979725, 1486.6916561497374],
#  [49.79545538979725, 1492.1820743382862],
#  [49.79545538979725, 1492.4356729039475],
#  [49.79545538979725, 1497.9260910924963],
#  [49.79545538979725, 1509.647483362648],
#  [49.79545538979725, 1534.6933400170692],
#  [49.79545538979725, 1541.2351694241731],
#  [49.79545538979725, 1548.054545147385],
#  [49.79545538979725, 1548.0668421583061],
#  [49.79545538979725, 1554.886217881518],
#  [49.79545538979725, 1555.201200063698],
#  [49.79545538979725, 1562.0205757869098],
#  [49.79545538979725, 1570.4322088380698],
#  [49.79545538979725, 1577.2515845612816],
#  [49.79545538979725, 1578.5574902123083],
#  [49.79545538979725, 1585.37686593552],
#  [49.79545538979725, 1599.5766935810216],
#  [49.79545538979725, 1607.6873494487866],
#  [49.79545538979725, 1607.70197495526],
#  [49.79545538979725, 1615.812630823025],
#  [49.79545538979725, 1624.28263869079],
#  [49.795455389797254, 1424.375385728702],
#  [49.795455389797254, 1428.61592242287],
#  [49.795455389797254, 1437.2692735802952],
#  [49.795455389797254, 1437.668965801602],
#  [49.795455389797254, 1446.3223169590274],
#  [49.795455389797254, 1455.7594484395681],
#  [49.795455389797254, 1458.3092705298152],
#  [49.795455389797254, 1464.0532872840254],
#  [49.795455389797254, 1466.9626216872402],
#  [49.795455389797254, 1472.7066384414507],
#  [49.795455389797254, 1476.3997531677815],
#  [49.795455389797254, 1481.434176677149],
#  [49.795455389797254, 1482.1437699219914],
#  [49.795455389797254, 1487.178193431359],
#  [54.20794601373131, 1526.777369645031],
#  [54.20794601373131, 1537.0692726269872],
#  [54.20794601373131, 1542.5596908155362],
#  [54.20794601373131, 1548.2933683395886],
#  [54.20794601373131, 1551.1684872742203],
#  [54.20794601373131, 1561.4603902561764],
#  [54.20794601373131, 1566.9508084447255],
#  [54.20794601373131, 1572.684485968778],
#  [54.207946013731316, 1512.9197907351834],
#  [54.207946013731316, 1521.9565386358338],
#  [54.207946013731316, 1531.3853607755264],
#  [54.207946013731316, 1531.8117931543986],
#  [54.207946013731316, 1537.3109083643726],
#  [54.207946013731316, 1541.6772637574825],
#  [54.207946013731316, 1546.347656265023],
#  [54.207946013731316, 1547.1676819460315],
#  [54.207946013731316, 1552.901359470084],
#  [54.207946013731316, 1555.7764784047156],
#  [54.207946013731316, 1556.2029107835879],
#  [54.207946013731316, 1566.0683813866717],
#  [54.207946013731316, 1571.5587995752207],
#  [54.207946013731316, 1577.2924770992734],
#  [54.207946013731316, 1585.167719739928],
#  [54.207946013731316, 1609.5588373691176],
#  [54.20794601373132, 1456.1873861189567],
#  [54.20794601373132, 1461.4543461195462],
#  [54.20794601373132, 1465.2241340196072],
#  [54.20794601373132, 1470.4910940201967],
#  [54.20794601373132, 1478.6971937038986],
#  [54.20794601373132, 1480.3368680107606],
#  [54.20794601373132, 1484.961476794895],
#  [54.20794601373132, 1485.60382801135],
#  [54.20794601373132, 1487.733941604549],
#  [54.20794601373132, 1491.0942461998989],
#  [54.20794601373132, 1491.5033062019988],
#  [54.20794601373132, 1493.9982246955453],
#  [54.20794601373132, 1498.3349789361318],
#  [54.20794601373132, 1500.5400541026493],
#  [54.20794601373132, 1502.3282424862728],
#  [54.20794601373132, 1502.8466755957024],
#  [54.20794601373132, 1505.4693368415237],
#  [54.20794601373132, 1507.3717268367823],
#  [54.20794601373132, 1508.0722592404827],
#  [54.20794601373132, 1508.3370937842515],
#  [54.20794601373132, 1509.1109586866987],
#  [54.20794601373132, 1514.070771308304],
#  [54.20794601373132, 1514.5060847421742],
#  [54.20794601373132, 1514.6013768752478],
#  [54.20794601373132, 1515.6527880938027],
#  [54.20794601373132, 1517.34023816449],
#  [54.20794601373132, 1520.0584860544031],
#  [54.20794601373132, 1520.3350543993001],
#  [54.20794601373132, 1520.7003456158955],
#  [54.20794601373132, 1521.1432062823517],
#  [54.20794601373132, 1522.4844608279357],
#  [54.20794601373132, 1526.3114934358357],
#  [54.20794601373132, 1526.3227691453994],
#  [54.20794601373132, 1526.564529766329],
#  [54.20794601373132, 1526.8768838064043],
#  [54.20794601373132, 1527.9748790164847],
#  [54.20794601373132, 1528.825626990134],
#  [54.20794601373132, 1529.6188187333275],
#  [54.20794601373132, 1529.7370935165459],
#  [54.20794601373132, 1531.3766832797098],
#  [54.20794601373132, 1532.5757765268318],
#  [54.20794601373132, 1532.8645985525036],
#  [54.20794601373132, 1533.7085565405373],
#  [54.20794601373132, 1535.1092369218766],
#  [54.20794601373132, 1536.197514288907],
#  [54.20794601373132, 1536.419784284894],
#  [54.20794601373132, 1537.8623748907844],
#  [54.20794601373132, 1539.117605933936],
#  [54.20794601373132, 1539.6962712866366],
#  [54.20794601373132, 1540.8429144459292],
#  [54.20794601373132, 1541.2228758359577],
#  [54.20794601373132, 1541.2319377982747],
#  [54.20794601373132, 1541.7313557936793],
#  [54.20794601373132, 1544.8498275076993],
#  [54.20794601373132, 1545.949278668069],
#  [54.20794601373132, 1546.2572993453252],
#  [54.20794601373132, 1546.4894172708632],
#  [54.20794601373132, 1546.8306291920285],
#  [54.20794601373132, 1550.3402456962483],
#  [54.20794601373132, 1550.9451227086436],
#  [54.20794601373132, 1550.9556473955183],
#  [54.20794601373132, 1551.5053153548631],
#  [54.20794601373132, 1551.5147788179138],
#  [54.20794601373132, 1551.9798354594122],
#  [54.20794601373132, 1552.9751088819378],
#  [54.20794601373132, 1553.0836365734608],
#  [54.20794601373132, 1554.281083085688],
#  [54.20794601373132, 1555.767800908899],
#  [54.20794601373132, 1556.073923220301],
#  [54.20794601373132, 1556.7627948274517],
#  [54.20794601373132, 1557.0051970064628],
#  [54.20794601373132, 1557.2094057996396],
#  [54.20794601373132, 1557.7135129834646],
#  [54.20794601373132, 1558.4655270704868],
#  [54.20794601373132, 1560.5340904671202],
#  [54.20794601373132, 1560.5886319180963],
#  [54.20794601373132, 1560.8109019140832],
#  [54.20794601373132, 1562.0616379664002],
#  [54.20794601373132, 1562.2433302632612],
#  [54.20794601373132, 1562.2532130160007],
#  [54.20794601373132, 1562.7388745305152],
#  [54.20794601373132, 1563.7512352067438],
#  [54.20794601373132, 1564.1992045945394],
#  [54.20794601373132, 1565.613993465147],
#  [54.20794601373132, 1565.623055427464],
#  [54.20794601373132, 1566.420224566614],
#  [54.20794601373132, 1567.0641445812917],
#  [54.20794601373132, 1567.7337484518102],
#  [54.20794601373132, 1567.986890540053],
#  [54.20794601373132, 1568.3146453478325],
#  [54.20794601373132, 1570.1869193406387],
#  [54.20794601373132, 1570.5829079408768],
#  [54.20794601373132, 1570.6484169745145],
#  [54.20794601373132, 1570.8805349000525],
#  [54.20794601373132, 1573.4571053563195],
#  [54.20794601373132, 1573.4674259758626],
#  [54.20794601373132, 1573.554582472006],
#  [54.20794601373132, 1573.8835203045032],
#  [54.20794601373132, 1575.8964329840524],
#  [54.20794601373132, 1575.905896447103],
#  [54.20794601373132, 1576.3709530886015],
#  [54.20794601373132, 1576.439926722071],
#  [54.20794601373132, 1577.7172658462687],
#  [54.20794601373132, 1578.6722007148771],
#  [54.20794601373132, 1579.190782880372],
#  [54.20794601373132, 1580.9916255486569],
#  [54.20794601373132, 1581.0050363656655],
#  [54.20794601373132, 1581.153912456641],
#  [54.20794601373132, 1581.396314635652],
#  [54.20794601373132, 1582.104630612654],
#  [54.20794601373132, 1584.9252080963097],
#  [54.20794601373132, 1586.6344478924505],
#  [54.20794601373132, 1586.64433064519],
#  [54.20794601373132, 1587.1299921597047],
#  [54.20794601373132, 1588.4420794423163],
#  [54.20794601373132, 1588.7855912463776],
#  [54.20794601373132, 1591.1554344860274],
#  [54.20794601373132, 1591.455262210481],
#  [54.20794601373132, 1592.1248660809995],
#  [54.20794601373132, 1592.3780081692425],
#  [54.20794601373132, 1592.9482746206404],
#  [54.20794601373132, 1596.2086293242432],
#  [54.20794601373132, 1596.2226343230286],
#  [54.20794601373132, 1596.9108726206161],
#  [54.20794601373132, 1597.3971864541732],
#  [54.20794601373132, 1597.4084418674597],
#  [54.20794601373132, 1597.8482229855088],
#  [54.20794601373132, 1597.858543605052],
#  [54.20794601373132, 1598.2746379336925],
#  [54.20794601373132, 1601.073555994879],
#  [54.20794601373132, 1603.5819005095614],
#  [54.20794601373132, 1603.6501938356057],
#  [54.20794601373132, 1604.3479156972671],
#  [54.20794601373132, 1605.3961539948548],
#  [54.20794601373132, 1612.8331970715055],
#  [54.20794601373132, 1615.5465521152166],
#  [54.20794601373132, 1617.879387766005],
#  [54.20794601373132, 1620.5997469534325],
#  [54.20794601373132, 1621.7883040833624],
#  [54.20794601373132, 1621.7995594966492],
#  [54.20794601373132, 1624.1211397341508],
#  [54.20794601373132, 1625.3164308426558],
#  [54.20794601373132, 1628.041311464795],
#  [54.20794601373132, 1628.7104028211975],
#  [54.20794601373132, 1631.5581828108016],
#  [54.20794601373132, 1637.1804106889624],
#  [54.20794601373132, 1637.4465405978262],
#  [54.20794601373132, 1642.2705053951943],
#  [54.20794601373132, 1644.883583674477],
#  [54.20794601373132, 1646.025692063201],
#  [54.20794601373132, 1648.51225736334],
#  [54.20794601373132, 1649.707548471845],
#  [54.20794601373132, 1655.9493004399908],
#  [54.20794601373132, 1661.8376582270155],
#  [54.20794601373132, 1669.2747013036662],
#  [54.20794601373133, 1441.689735357678],
#  [54.20794601373133, 1450.7264832583285],
#  [54.20794601373133, 1451.1438843063265],
#  [54.20794601373133, 1455.3344743888238],
#  [54.20794601373133, 1460.1466279022045],
#  [54.20794601373133, 1460.180632206977],
#  [54.20794601373133, 1460.6078335482634],
#  [54.20794601373133, 1464.7886233374722],
#  [54.20794601373133, 1465.2158246787587],
#  [54.20794601373133, 1465.874793548853],
#  [54.20794601373133, 1469.600776850853],
#  [54.20794601373133, 1469.8321251501025],
#  [54.20794601373133, 1470.0449650288044],
#  [54.20794601373133, 1470.4827846793482],
#  [54.20794601373133, 1474.6442786634832],
#  [54.20794601373133, 1474.6529561592997],
#  [54.20794601373133, 1475.079388538172],
#  [54.20794601373133, 1475.099085150692],
#  [54.20794601373133, 1475.311925029394],
#  [54.20794601373133, 1479.4651096726805],
#  [54.20794601373133, 1479.6873796686673],
#  [54.20794601373133, 1479.9112386640727],
#  [54.20794601373133, 1479.9199161598892],
#  [54.20794601373133, 1480.3463485387615],
#  [54.20794601373133, 1483.1176411332053],
#  [54.20794601373133, 1484.490471219731],
#  [54.20794601373133, 1484.499533182048],
#  [54.20794601373133, 1484.73206967327],
#  [54.20794601373133, 1484.9448591412558],
#  [54.20794601373133, 1484.9543396692568],
#  [54.20794601373133, 1487.7256322637006],
#  [54.20794601373133, 1489.3819242242016],
#  [54.20794601373133, 1489.5248947290986],
#  [54.20794601373133, 1489.7570126546366],
#  [54.20794601373133, 1489.7574312203205],
#  [54.20794601373133, 1489.7664931826375],
#  [54.20794601373133, 1490.2118191418454],
#  [54.20794601373133, 1492.3419327350443],
#  [54.20794601373133, 1492.5547726137463],
#  [54.20794601373133, 1493.989915354697],
#  [54.20794601373133, 1494.7729107386365],
#  [54.20794601373133, 1494.7823742016872],
#  [54.20794601373133, 1494.791854729688],
#  [54.20794601373133, 1495.023972655226],
#  [54.20794601373133, 1495.7022373303942],
#  [54.20794601373133, 1495.9237536313055],
#  [54.20794601373133, 1497.154086248425],
#  [54.20794601373133, 1497.1627637442416],
#  [54.20794601373133, 1497.5891961231139],
#  [54.20794601373133, 1498.6062158260406],
#  [54.20794601373133, 1498.8190557047426],
#  [54.20794601373133, 1500.030390211225],
#  [54.20794601373133, 1500.039870739226],
#  [54.20794601373133, 1500.0493342022767],
#  [54.20794601373133, 1500.514390843775],
#  [54.20794601373133, 1500.5317447618008],
#  [54.20794601373133, 1501.9749172576223],
#  [54.20794601373133, 1502.1971872536092],
#  [54.20794601373133, 1502.7554263654386],
#  [54.20794601373133, 1503.4183693394214],
#  [54.20794601373133, 1503.427046835238],
#  [54.20794601373133, 1503.8534792141102],
#  [54.20794601373133, 1505.1480452331446],
#  [54.20794601373133, 1505.2973502118145],
#  [54.20794601373133, 1505.3608851118465],
#  [54.20794601373133, 1505.5109256470346],
#  [54.20794601373133, 1505.5397523908255],
#  [54.20794601373133, 1506.936233616768],
#  [54.20794601373133, 1507.000278804673],
#  [54.20794601373133, 1507.00934076699],
#  [54.20794601373133, 1507.3634174959338],
#  [54.20794601373133, 1507.4546667261977],
#  [54.20794601373133, 1508.2392003486186],
#  [54.20794601373133, 1508.4614703446055],
#  [54.20794601373133, 1509.8897842708304],
#  [54.20794601373133, 1509.9601987465253],
#  [54.20794601373133, 1509.9688762423418],
#  [54.20794601373133, 1510.395308621214],
#  [54.20794601373133, 1510.777885647624],
#  [54.20794601373133, 1510.7877684003633],
#  [54.20794601373133, 1511.7483871301488],
#  [54.20794601373133, 1511.9797179672776],
#  [54.20794601373133, 1512.0347023140405],
#  [54.20794601373133, 1512.1925578459795],
#  [54.20794601373133, 1512.2668202395785],
#  [54.20794601373133, 1512.680250370978],
#  [54.20794601373133, 1512.9450849147468],
#  [54.20794601373133, 1513.2645618956692],
#  [54.20794601373133, 1513.2736238579862],
#  [54.20794601373133, 1513.718949817194],
#  [54.20794601373133, 1514.4977754013257],
#  [54.20794601373133, 1514.7810297557226],
#  [54.20794601373133, 1515.0032997517094],
#  [54.20794601373133, 1516.268303836173],
#  [54.20794601373133, 1516.7737486771994],
#  [54.20794601373133, 1516.7918714806583],
#  [54.20794601373133, 1516.8005489764748],
#  [54.20794601373133, 1517.226981355347],
#  [54.20794601373133, 1517.2827183235784],
#  [54.20794601373133, 1517.292181786629],
#  [54.20794601373133, 1517.4924038843587],
#  [54.20794601373133, 1517.7572384281275],
#  [54.20794601373133, 1518.2989854050368],
#  [54.20794601373133, 1518.5311033305748],
#  [54.20794601373133, 1518.6787624387994],
#  [54.20794601373133, 1519.1140758726694],
#  [54.20794601373133, 1519.209368005743],
#  [54.20794601373133, 1519.3269157513714],
#  [54.20794601373133, 1519.8063913027731],
#  [54.20794601373133, 1519.8154532650901],
#  [54.20794601373133, 1520.260779224298],
#  [54.20794601373133, 1521.6127024898556],
#  [54.20794601373133, 1521.8349724858424],
#  [54.20794601373133, 1521.9482292949854],
#  [54.20794601373133, 1521.9916607406822],
#  [54.20794601373133, 1522.0217646867372],
#  [54.20794601373133, 1522.5177654314093],
#  [54.20794601373133, 1522.540197796167],
#  [54.20794601373133, 1522.782599975178],
#  [54.20794601373133, 1523.49091595218],
#  [54.20794601373133, 1523.5470014145747],
#  [54.20794601373133, 1523.5564648776253],
#  [54.20794601373133, 1523.9262293860502],
#  [54.20794601373133, 1523.9349068818667],
#  [54.20794601373133, 1524.0215215191238],
#  [54.20794601373133, 1524.361339260739],
#  [54.20794601373133, 1524.6664771848984],
#  [54.20794601373133, 1524.8408148121407],
#  [54.20794601373133, 1524.9430455297954],
#  [54.20794601373133, 1525.0729327376787],
#  [54.20794601373133, 1525.1207930452022],
#  [54.20794601373133, 1525.751197412847],
#  [54.20794601373133, 1526.6380640369061],
#  [54.20794601373133, 1526.6471259992231],
#  [54.20794601373133, 1527.092451958431],
#  [54.20794601373133, 1527.5023001225468],
#  [54.20794601373133, 1527.7657814409472],
#  [54.20794601373133, 1528.0207332319765],
#  [54.20794601373133, 1528.030615984716],
#  [54.20794601373133, 1528.5162774992307],
#  [54.20794601373133, 1528.7470603952474],
#  [54.20794601373133, 1528.8044808871632],
#  [54.20794601373133, 1528.9693303912343],
#  [54.20794601373133, 1529.0468830661744],
#  [54.20794601373133, 1529.4786306982792],
#  [54.20794601373133, 1529.7287841756975],
#  [54.20794601373133, 1529.7551990431762],
#  [54.20794601373133, 1530.0888308216786],
#  [54.20794601373133, 1530.0982942847293],
#  [54.20794601373133, 1530.5633509262277],
#  [54.20794601373133, 1530.919484566331],
#  [54.20794601373133, 1530.9307602758947],
#  [54.20794601373133, 1531.4848749368996],
#  [54.20794601373133, 1531.6724875462737],
#  [54.20794601373133, 1531.9046054718117],
#  [54.20794601373133, 1532.58287014698],
#  [54.20794601373133, 1533.225657027056],
#  [54.20794601373133, 1533.2460744194407],
#  [54.20794601373133, 1533.2463168767567],
#  [54.20794601373133, 1533.5111514205255],
#  [54.20794601373133, 1533.7642935087686],
#  [54.20794601373133, 1533.772421942298],
#  [54.20794601373133, 1533.781483904615],
#  [54.20794601373133, 1534.2268098638228],
#  [54.20794601373133, 1534.2850163229728],
#  [54.20794601373133, 1534.2948990757122],
#  [54.20794601373133, 1534.3450846470412],
#  [54.20794601373133, 1534.5039922453298],
#  [54.20794601373133, 1534.5579245257431],
#  [54.20794601373133, 1534.7805605902267],
#  [54.20794601373133, 1535.3463102942671],
#  [54.20794601373133, 1535.5887124732783],
#  [54.20794601373133, 1535.7316380797117],
#  [54.20794601373133, 1535.7429137892755],
#  [54.20794601373133, 1536.2970284502803],
#  [54.20794601373133, 1536.9205035558116],
#  [54.20794601373133, 1536.9299670188623],
#  [54.20794601373133, 1537.183767657327],
#  [54.20794601373133, 1537.3950236603607],
#  [54.20794601373133, 1537.472589682999],
#  [54.20794601373133, 1537.854065549936],
#  [54.20794601373133, 1538.3165476710326],
#  [54.20794601373133, 1538.8068454516656],
#  [54.20794601373133, 1538.969673781266],
#  [54.20794601373133, 1539.0389633772036],
#  [54.20794601373133, 1539.157238160422],
#  [54.20794601373133, 1539.1659156562384],
#  [54.20794601373133, 1539.2345083250348],
#  [54.20794601373133, 1539.244828944578],
#  [54.20794601373133, 1539.5923480351107],
#  [54.20794601373133, 1539.7172280523719],
#  [54.20794601373133, 1539.7520082548676],
#  [54.20794601373133, 1539.7754345115218],
#  [54.20794601373133, 1540.0285765997646],
#  [54.20794601373133, 1540.7569996267623],
#  [54.20794601373133, 1540.768275336326],
#  [54.20794601373133, 1540.8268457300767],
#  [54.20794601373133, 1540.8367284828162],
#  [54.20794601373133, 1541.322389997331],
#  [54.20794601373133, 1541.9959211707078],
#  [54.20794601373133, 1542.1779830284001],
#  [54.20794601373133, 1542.2847431963796],
#  [54.20794601373133, 1542.4203852074113],
#  [54.20794601373133, 1542.4703660212797],
#  [54.20794601373133, 1542.6832058999817],
#  [54.20794601373133, 1543.1287011844133],
#  [54.20794601373133, 1543.7255970644312],
#  [54.20794601373133, 1543.9780691696192],
#  [54.20794601373133, 1544.0548614612035],
#  [54.20794601373133, 1544.0643249242542],
#  [54.20794601373133, 1544.200339165606],
#  [54.20794601373133, 1544.304262417132],
#  [54.20794601373133, 1544.5293815657526],
#  [54.20794601373133, 1544.9681858490874],
#  [54.20794601373133, 1545.2325436906772],
#  [54.20794601373133, 1545.4509055764245],
#  [54.20794601373133, 1545.498791416031],
#  [54.20794601373133, 1545.5091120355742],
#  [54.20794601373133, 1546.0050156363002],
#  [54.20794601373133, 1546.016291345864],
#  [54.20794601373133, 1546.3172639186257],
#  [54.20794601373133, 1546.3393469241746],
#  [54.20794601373133, 1546.5704060068688],
#  [54.20794601373133, 1547.0212827177584],
#  [54.20794601373133, 1547.2825195346604],
#  [54.20794601373133, 1547.291197030477],
#  [54.20794601373133, 1547.3101047434302],
#  [54.20794601373133, 1547.6585184642097],
#  [54.20794601373133, 1547.6684012169492],
#  [54.20794601373133, 1547.7176294093492],
#  [54.20794601373133, 1548.154062731464],
#  [54.20794601373133, 1548.537750577812],
#  [54.20794601373133, 1549.0034307166698],
#  [54.20794601373133, 1549.0124926789867],
#  [54.20794601373133, 1549.1164159305126],
#  [54.20794601373133, 1549.312340933792],
#  [54.20794601373133, 1549.4578186381946],
#  [54.20794601373133, 1549.5547431128032],
#  [54.20794601373133, 1550.2630590898052],
#  [54.20794601373133, 1550.5572697985642],
#  [54.20794601373133, 1550.9559005951864],
#  [54.20794601373133, 1551.2324689400834],
#  [54.20794601373133, 1551.4386203225238],
#  [54.20794601373133, 1551.4855510721097],
#  [54.20794601373133, 1551.4968267816735],
#  [54.20794601373133, 1552.040620823135],
#  [54.20794601373133, 1552.0509414426783],
#  [54.20794601373133, 1552.1033505438577],
#  [54.20794601373133, 1552.2692987272962],
#  [54.20794601373133, 1552.3256205398445],
#  [54.20794601373133, 1552.558120752968],
#  [54.20794601373133, 1553.1489366527587],
#  [54.20794601373133, 1553.4020787410018],
#  [54.20794601373133, 1553.5631121248625],
#  [54.20794601373133, 1554.0378542260373],
#  [54.20794601373133, 1554.1417774775632],
#  [54.20794601373133, 1554.2699721515753],
#  [54.20794601373133, 1554.7928763696016],
#  [54.20794601373133, 1554.802759122341],
#  [54.20794601373133, 1554.9482368267436],
#  [54.20794601373133, 1555.2884206368558],
#  [54.20794601373133, 1555.369423311945],
#  [54.20794601373133, 1556.2507738359045],
#  [54.20794601373133, 1557.1287120909083],
#  [54.20794601373133, 1557.1377740532253],
#  [54.20794601373133, 1557.208907976619],
#  [54.20794601373133, 1557.2201836861827],
#  [54.20794601373133, 1557.583100012433],
#  [54.20794601373133, 1557.691627703956],
#  [54.20794601373133, 1557.7498341631058],
#  [54.20794601373133, 1557.7742983471876],
#  [54.20794601373133, 1558.0386561887776],
#  [54.20794601373133, 1558.8111281344004],
#  [54.20794601373133, 1558.872293557268],
#  [54.20794601373133, 1558.8826141768113],
#  [54.20794601373133, 1558.8890742161832],
#  [54.20794601373133, 1559.2858702355752],
#  [54.20794601373133, 1559.2953336986259],
#  [54.20794601373133, 1559.389793487101],
#  [54.20794601373133, 1559.7603903401243],
#  [54.20794601373133, 1560.2832945581506],
#  [54.20794601373133, 1560.3947848589955],
#  [54.20794601373133, 1560.5364366463937],
#  [54.20794601373133, 1560.6819143507962],
#  [54.20794601373133, 1561.276135382955],
#  [54.20794601373133, 1562.1631356002758],
#  [54.20794601373133, 1562.3952535258138],
#  [54.20794601373133, 1562.5037812173368],
#  [54.20794601373133, 1563.073518200982],
#  [54.20794601373133, 1563.1745894228886],
#  [54.20794601373133, 1563.473191067615],
#  [54.20794601373133, 1563.701227729564],
#  [54.20794601373133, 1563.762013093287],
#  [54.20794601373133, 1564.29166357021],
#  [54.20794601373133, 1564.5433497081638],
#  [54.20794601373133, 1564.6059710813206],
#  [54.20794601373133, 1564.785751887175],
#  [54.20794601373133, 1564.8703289229106],
#  [54.20794601373133, 1565.1420815976155],
#  [54.20794601373133, 1565.494067864177],
#  [54.20794601373133, 1565.6428008685334],
#  [54.20794601373133, 1566.0066514626599],
#  [54.20794601373133, 1566.0169720822032],
#  [54.20794601373133, 1566.524151392493],
#  [54.20794601373133, 1566.6696290968955],
#  [54.20794601373133, 1567.4111516098137],
#  [54.20794601373133, 1567.4206150728644],
#  [54.20794601373133, 1567.5291427643874],
#  [54.20794601373133, 1567.8856717143628],
#  [54.20794601373133, 1568.7265892766145],
#  [54.20794601373133, 1568.8071957250347],
#  [54.20794601373133, 1569.427596804321],
#  [54.20794601373133, 1569.4388725138847],
#  [54.20794601373133, 1569.9542351109963],
#  [54.20794601373133, 1570.0150204747192],
#  [54.20794601373133, 1570.0238851439733],
#  [54.20794601373133, 1570.0337678967128],
#  [54.20794601373133, 1570.5194294112275],
#  [54.20794601373133, 1570.59368582742],
#  [54.20794601373133, 1571.0282156971093],
#  [54.20794601373133, 1571.123336304343],
#  [54.20794601373133, 1571.4817826102762],
#  [54.20794601373133, 1571.672135711787],
#  [54.20794601373133, 1571.7403289867125],
#  [54.20794601373133, 1572.0046868283025],
#  [54.20794601373133, 1572.6686310824023],
#  [54.20794601373133, 1572.7771587739253],
#  [54.20794601373133, 1572.9110332614134],
#  [54.20794601373133, 1572.9226364783278],
#  [54.20794601373133, 1573.6193492384155],
#  [54.20794601373133, 1573.9746052861524],
#  [54.20794601373133, 1574.794910471134],
#  [54.20794601373133, 1574.9795966580468],
#  [54.20794601373133, 1575.5143033325223],
#  [54.20794601373133, 1575.6918798953172],
#  [54.20794601373133, 1575.7674454207654],
#  [54.20794601373133, 1575.84036921049],
#  [54.20794601373133, 1575.9807019209888],
#  [54.20794601373133, 1576.4842892251677],
#  [54.20794601373133, 1576.5071441573268],
#  [54.20794601373133, 1576.8466932088522],
#  [54.20794601373133, 1577.7280437328118],
#  [54.20794601373133, 1577.7347899917086],
#  [54.20794601373133, 1578.1491665182118],
#  [54.20794601373133, 1578.1590492709513],
#  [54.20794601373133, 1578.1625736025012],
#  [54.20794601373133, 1578.2576942097348],
#  [54.20794601373133, 1578.4915114349985],
#  [54.20794601373133, 1578.644710785466],
#  [54.20794601373133, 1579.455140721962],
#  [54.20794601373133, 1579.6070639845148],
#  [54.20794601373133, 1580.2276126675847],
#  [54.20794601373133, 1580.8657307575406],
#  [54.20794601373133, 1581.0479178525663],
#  [54.20794601373133, 1581.2376602370316],
#  [54.20794601373133, 1581.247980856575],
#  [54.20794601373133, 1581.5096507722183],
#  [54.20794601373133, 1581.7551601668647],
#  [54.20794601373133, 1582.2337093024212],
#  [54.20794601373133, 1582.7601515387591],
#  [54.20794601373133, 1582.8123746551219],
#  [54.20794601373133, 1582.974727115882],
#  [54.20794601373133, 1583.2801918453724],
#  [54.20794601373133, 1583.3036649483793],
#  [54.20794601373133, 1583.6395847067608],
#  [54.20794601373133, 1583.892726795004],
#  [54.20794601373133, 1583.981051114244],
#  [54.20794601373133, 1584.6324255315653],
#  [54.20794601373133, 1585.1784976264712],
#  [54.20794601373133, 1585.5996166791522],
#  [54.20794601373133, 1585.6130274961608],
#  [54.20794601373133, 1585.7081481033943],
#  [54.20794601373133, 1585.860071365947],
#  [54.20794601373133, 1586.1137467670785],
#  [54.20794601373133, 1586.7576667817561],
#  [54.20794601373133, 1586.9713377610842],
#  [54.20794601373133, 1587.2356956026742],
#  [54.20794601373133, 1588.0000886629325],
#  [54.20794601373133, 1588.008167548297],
#  [54.20794601373133, 1588.0923453587532],
#  [54.20794601373133, 1588.3290264954298],
#  [54.20794601373133, 1589.0653820365542],
#  [54.20794601373133, 1589.3629416112701],
#  [54.20794601373133, 1589.3732622308135],
#  [54.20794601373133, 1589.533199226805],
#  [54.20794601373133, 1589.8804415411032],
#  [54.20794601373133, 1589.9467325605137],
#  [54.20794601373133, 1590.411770192533],
#  [54.20794601373133, 1590.4251810095416],
#  [54.20794601373133, 1590.8854329129977],
#  [54.20794601373133, 1591.4315050079035],
#  [54.20794601373133, 1591.594282202888],
#  [54.20794601373133, 1592.2382022175657],
#  [54.20794601373133, 1592.9590525071835],
#  [54.20794601373133, 1593.0500705728116],
#  [54.20794601373133, 1593.1177069058037],
#  [54.20794601373133, 1593.2481046724704],
#  [54.20794601373133, 1593.393582376873],
#  [54.20794601373133, 1593.4887029841066],
#  [54.20794601373133, 1593.5770425049677],
#  [54.20794601373133, 1594.3453527401857],
#  [54.20794601373133, 1595.0966191353227],
#  [54.20794601373133, 1595.3609769769128],
#  [54.20794601373133, 1595.4371317395835],
#  [54.20794601373133, 1595.4505425565922],
#  [54.20794601373133, 1596.0632533409762],
#  [54.20794601373133, 1596.1334489225355],
#  [54.20794601373133, 1596.199739941946],
#  [54.20794601373133, 1597.3176391073973],
#  [54.20794601373133, 1597.8622240861923],
#  [54.20794601373133, 1597.961559122075],
#  [54.20794601373133, 1598.2057358902537],
#  [54.20794601373133, 1598.3657229153416],
#  [54.20794601373133, 1598.72864010828],
#  [54.20794601373133, 1599.0575779407773],
#  [54.20794601373133, 1599.2120598886158],
#  [54.20794601373133, 1599.3707142872363],
#  [54.20794601373133, 1600.6851477491214],
#  [54.20794601373133, 1600.69855856613],
#  [54.20794601373133, 1600.8166204547385],
#  [54.20794601373133, 1600.830625453524],
#  [54.20794601373133, 1600.875406854357],
#  [54.20794601373133, 1601.084333881422],
#  [54.20794601373133, 1601.5188637511114],
#  [54.20794601373133, 1601.613984358345],
#  [54.20794601373133, 1602.8826290641878],
#  [54.20794601373133, 1602.887585633243],
#  [54.20794601373133, 1603.2310974373042],
#  [54.20794601373133, 1603.8462583511512],
#  [54.20794601373133, 1604.4519970127892],
#  [54.20794601373133, 1604.6187302967742],
#  [54.20794601373133, 1604.7809348452865],
#  [54.20794601373133, 1605.1777413348855],
#  [54.20794601373133, 1605.6287739681193],
#  [54.20794601373133, 1605.6427789669046],
#  [54.20794601373133, 1605.9007684014075],
#  [54.20794601373133, 1606.165683184931],
#  [54.20794601373133, 1606.1790940019396],
#  [54.20794601373133, 1606.3310172644922],
#  [54.20794601373133, 1607.3373412628544],
#  [54.20794601373133, 1607.6947825775685],
#  [54.20794601373133, 1608.1356016427808],
#  [54.20794601373133, 1608.4791134468421],
#  [54.20794601373133, 1608.9559068277624],
#  [54.20794601373133, 1609.5363279350993],
#  [54.20794601373133, 1609.5696152556604],
#  [54.20794601373133, 1610.00414512535],
#  [54.20794601373133, 1610.0992657325837],
#  [54.20794601373133, 1610.1684938523713],
#  [54.20794601373133, 1610.180247949777],
#  [54.20794601373133, 1610.6541355151699],
#  [54.20794601373133, 1610.6681405139552],
#  [54.20794601373133, 1611.1487844109454],
#  [54.20794601373133, 1611.3563788115428],
#  [54.20794601373133, 1611.4307487163178],
#  [54.20794601373133, 1611.8890400894402],
#  [54.20794601373133, 1611.9024509064488],
#  [54.20794601373133, 1612.720144124619],
#  [54.20794601373133, 1613.303022709124],
#  [54.20794601373133, 1613.6161370785903],
#  [54.20794601373133, 1613.7680603411432],
#  [54.20794601373133, 1613.9596488826517],
#  [54.20794601373133, 1614.8162986387308],
#  [54.20794601373133, 1615.822622637093],
#  [54.20794601373133, 1615.9021515247077],
#  [54.20794601373133, 1615.916156523493],
#  [54.20794601373133, 1616.6043948210806],
#  [54.20794601373133, 1616.629319846755],
#  [54.20794601373133, 1616.6706858404912],
#  [54.20794601373133, 1616.9996236729885],
#  [54.20794601373133, 1617.4411882020008],
#  [54.20794601373133, 1617.968160134157],
#  [54.20794601373133, 1618.7934218881937],
#  [54.20794601373133, 1619.3394939830996],
#  [54.20794601373133, 1619.5560300905563],
#  [54.20794601373133, 1619.683005787161],
#  [54.20794601373133, 1619.8416601857814],
#  [54.20794601373133, 1621.3826869605173],
#  [54.20794601373133, 1621.3966919593026],
#  [54.20794601373133, 1622.0849302568902],
#  [54.20794601373133, 1622.2533417153816],
#  [54.20794601373133, 1622.3526767512642],
#  [54.20794601373133, 1622.861728798775],
#  [54.20794601373133, 1623.4486955699665],
#  [54.20794601373133, 1623.5056488134524],
#  [54.20794601373133, 1624.0414378977316],
#  [54.20794601373133, 1624.1077289171421],
#  [54.20794601373133, 1625.0896761953193],
#  [54.20794601373133, 1625.2077380839278],
#  [54.20794601373133, 1627.1060438650265],
#  [54.20794601373133, 1627.120048863812],
#  [54.20794601373133, 1627.2787032624321],
#  [54.20794601373133, 1627.8082871613994],
#  [54.20794601373133, 1629.1720524744758],
#  [54.20794601373133, 1629.5219733335412],
#  [54.20794601373133, 1629.9960867041668],
#  [54.20794601373133, 1630.0198915973085],
#  [54.20794601373133, 1630.325024536664],
#  [54.20794601373133, 1630.5702116311288],
#  [54.20794601373133, 1630.6394397509164],
#  [54.20794601373133, 1631.901694614863],
#  [54.20794601373133, 1632.52671927197],
#  [54.20794601373133, 1633.3183939516928],
#  [54.20794601373133, 1634.5596114815605],
#  [54.20794601373133, 1634.5713655789662],
#  [54.20794601373133, 1635.045253144359],
#  [54.20794601373133, 1635.2453302380504],
#  [54.20794601373133, 1636.293568535638],
#  [54.20794601373133, 1637.4331297808176],
#  [54.20794601373133, 1638.0072547077796],
#  [54.20794601373133, 1638.0764828275674],
#  [54.20794601373133, 1638.1305474650735],
#  [54.20794601373133, 1639.3247326927285],
#  [54.20794601373133, 1639.3387376915139],
#  [54.20794601373133, 1640.0269759891014],
#  [54.20794601373133, 1640.293269153897],
#  [54.20794601373133, 1641.3907413021777],
#  [54.20794601373133, 1641.7884018194577],
#  [54.20794601373133, 1643.155909012124],
#  [54.20794601373133, 1643.7306116122888],
#  [54.20794601373133, 1644.5552379300784],
#  [54.20794601373133, 1645.2270954785386],
#  [54.20794601373133, 1645.7738045897065],
#  [54.20794601373133, 1646.6005553328384],
#  [54.20794601373133, 1647.4640190657524],
#  [54.20794601373133, 1647.8967664426416],
#  [54.20794601373133, 1648.403925021662],
#  [54.20794601373133, 1650.6336831936962],
#  [54.20794601373133, 1651.4971614942158],
#  [54.20794601373133, 1651.625916879889],
#  [54.20794601373133, 1651.9788943291915],
#  [54.20794601373133, 1651.9922810067292],
#  [54.20794601373133, 1652.650133556404],
#  [54.20794601373133, 1652.6641385551893],
#  [54.20794601373133, 1653.352376852777],
#  [54.20794601373133, 1653.8844604574715],
#  [54.20794601373133, 1654.7161421658534],
#  [54.20794601373133, 1655.0305573801056],
#  [54.20794601373133, 1655.445836707077],
#  [54.20794601373133, 1656.873932889427],
#  [54.20794601373133, 1659.4159374058422],
#  [54.20794601373133, 1659.6078173619808],
#  [54.20794601373133, 1660.4711982541276],
#  [54.20794601373133, 1660.7894199294278],
#  [54.20794601373133, 1662.3544683252364],
#  [54.20794601373133, 1662.4676004567564],
#  [54.20794601373133, 1663.7158503219177],
#  [54.20794601373133, 1665.7192142636654],
#  [54.20794601373133, 1667.1685074979816],
#  [54.20794601373133, 1668.0778252297457],
#  [54.20794601373133, 1668.9463555592677],
#  [54.20794601373133, 1671.199749699475],
#  [54.20794601373133, 1671.8265061896827],
#  [54.20794601373133, 1676.3700119583805],
#  [54.20794601373133, 1676.3833986359186],
#  [54.20794601373133, 1676.9231066039843],
#  [54.20794601373133, 1677.0412511855934],
#  [54.20794601373133, 1680.2965140574477],
#  [54.20794601373133, 1683.0311140671117],
#  [54.20794601373133, 1683.8070550350315],
#  [54.20794601373133, 1685.1519070533582],
#  [54.20794601373133, 1689.1417954316862],
#  [54.20794601373133, 1691.5596251271709],
#  [54.20794601373133, 1693.6219149211233],
#  [54.20794601373133, 1702.4671962953616],
#  [54.20794601373133, 1707.422231696301],
#  [54.20794601373133, 1715.5328875640662],
#  [54.20794601373133, 1723.9876494176688],
#  [54.20794601373133, 1724.002895431831],
#  [54.20794601373133, 1732.457657285434],
#  [54.20794601373133, 1732.8481768060697],
#  [54.20794601373133, 1741.3029386596722],
#  [54.20794601373134, 1433.0207800807543],
#  [54.20794601373134, 1437.2613167749223],
#  [54.20794601373134, 1446.1101827869848],
#  [54.20794601373134, 1446.3143601536544],
#  [54.20794601373134, 1450.71817391748],
#  [54.20794601373134, 1455.3511080543049],
#  [54.20794601373134, 1455.5643317356332],
#  [54.20794601373134, 1459.9590991848002],
#  [54.20794601373134, 1460.1723228661285],
#  [54.20794601373134, 1464.771252698181],
#  [54.20794601373134, 1465.0014632161742],
#  [54.20794601373134, 1466.9546648818675],
#  [54.20794601373134, 1469.6094543466695],
#  [54.20794601373134, 1470.0358867255418],
#  [54.20794601373134, 1472.6986816360777],
#  [54.20794601373134, 1474.4216078600502],
#  [54.20794601373134, 1474.643877856037],
#  [54.20794601373134, 1475.991412782518],
#  [54.20794601373134, 1479.4469694071008],
#  [54.20794601373134, 1479.4560313694178],
#  [54.20794601373134, 1480.5994039130132],
#  [54.20794601373134, 1481.7354295367281],
#  [54.20794601373134, 1484.4813929164684],
#  [54.20794601373134, 1485.411557426394],
#  [54.20794601373134, 1486.3434206672234],
#  [54.20794601373134, 1491.1041467736713],
#  [54.20794601373134, 1491.1555741806042],
#  [54.20794601373134, 1495.7121379041666],
#  [54.20794601373134, 1496.5945649622201],
#  [54.20794601373134, 1496.8481635278815],
#  [54.20794601373134, 1500.5242914175474],
#  [54.20794601373134, 1501.2025560927154],
#  [54.20794601373134, 1501.4561546583768],
#  [54.20794601373134, 1502.3385817164303],
#  [54.20794601373134, 1505.549652964598],
#  [54.20794601373134, 1506.0147096060962],
#  [54.20794601373134, 1506.2683081717576],
#  [54.20794601373134, 1506.9465728469256],
#  ...]
